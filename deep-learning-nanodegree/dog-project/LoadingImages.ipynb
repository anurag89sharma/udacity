# %%
import os
import cv2
import matplotlib.pyplot as plt
from keras.preprocessing import image
# %matplotlib inline

print(os.getcwd())
os.listdir('test-images')

img_path = 'test-images'

print(os.listdir(img_path))

for img in os.listdir(img_path):
    
    path = os.path.join(os.getcwd(), img_path, img)
    print(path)
    img = image.load_img(path, target_size=(224, 224))
    display_image(path)
# Out:
# /media/sf_D_DRIVE/Work/Study/udacity/deep-learning-nanodegree/dog-project
# ['car-image.jpeg', 'cartoon-image.jpeg', 'dog-image1.jpeg', 'dog-image2.jpeg', 'human-image.jpeg', 'human-image2.jpeg', 'monkey-image.jpeg']
# /media/sf_D_DRIVE/Work/Study/udacity/deep-learning-nanodegree/dog-project/test-images/car-image.jpeg
# /media/sf_D_DRIVE/Work/Study/udacity/deep-learning-nanodegree/dog-project/test-images/cartoon-image.jpeg
# /media/sf_D_DRIVE/Work/Study/udacity/deep-learning-nanodegree/dog-project/test-images/dog-image1.jpeg
# /media/sf_D_DRIVE/Work/Study/udacity/deep-learning-nanodegree/dog-project/test-images/dog-image2.jpeg
# /media/sf_D_DRIVE/Work/Study/udacity/deep-learning-nanodegree/dog-project/test-images/human-image.jpeg
# /media/sf_D_DRIVE/Work/Study/udacity/deep-learning-nanodegree/dog-project/test-images/human-image2.jpeg
# /media/sf_D_DRIVE/Work/Study/udacity/deep-learning-nanodegree/dog-project/test-images/monkey-image.jpeg

# %%
def display_image(img_path):
    # print("Hello, {}!".format(msg1))
    # load color (BGR) image
    img = cv2.imread(img_path, 1)
    # convert BGR image to grayscale
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    # convert BGR image to RGB for plotting
    cv_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    # display the image, along with bounding box
    plt.imshow(cv_rgb)
    plt.show()
    # print("You look like: {}".format(msg2))
