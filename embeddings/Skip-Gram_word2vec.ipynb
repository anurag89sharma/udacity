# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()
# Out:
# Text8 Dataset: 31.4MB [03:22, 155kB/s]

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to convert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
## Your code here
import random
from collections import Counter

def sub_sampling(full_list, threshold):
    total_count = len(full_list)
    word_counts = Counter(full_list)
    
    discard_prob = {}
    for key, val in word_counts.items():
        prob = 1 - np.sqrt((threshold * total_count)/val)
        discard_prob[key] = prob
    
    return [word for word in full_list if discard_prob[word] < random.random()]

train_words = sub_sampling(int_words, 1e-5)

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    # Your code here
    R = np.random.randint(1, window_size + 1)
    start = idx - R if idx-R > 0 else 0
    stop = idx + R
    target = set(words[start: idx] + words[idx + 1: stop + 1])
    return list(target)

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, shape=(None), name="inputs")
    labels = tf.placeholder(tf.int32, shape=(None, 1), name="labels")

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding = 300
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform(shape=(n_vocab, n_embedding), minval=-1, maxval=1))
    embed = tf.nn.embedding_lookup(embedding, inputs)

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal(shape=(n_vocab, n_embedding), stddev=0.1))
    softmax_b = tf.Variable(tf.zeros(n_vocab))
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, labels, embed, n_sampled, n_vocab) 
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)
# Out:
# WARNING:tensorflow:From /home/dimension/.virtualenvs/data-science/lib/python3.5/site-packages/tensorflow/python/ops/nn_impl.py:1344: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See @{tf.nn.softmax_cross_entropy_with_logits_v2}.

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))
# Out:
# WARNING:tensorflow:From <ipython-input-16-2aa168c49a56>:13: calling reduce_sum (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.7668 0.5669 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.7389 0.5790 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.6313 0.5589 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.7061 0.5183 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.6411 0.6128 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.6452 0.5335 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.6750 0.4876 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.6520 0.4507 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.5604 0.4397 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.5408 0.4300 sec/batch
# Nearest to th: mash, joseph, durables, galena, fees, abrasives, modellers, abstract,
# Nearest to four: jovis, atat, overlying, temporarily, pacifists, expounded, indoors, gere,
# Nearest to american: haploid, anglican, suffocation, palmeiro, triathlon, mckay, sepsis, detract,
# Nearest to may: pesce, risky, mode, silkworth, brian, wiesner, facilitate, softened,
# Nearest to nine: onboard, generating, slava, hitting, cctld, presences, lurid, maclachlan,
# Nearest to an: contrabassoon, cro, horrified, eyeglasses, leges, alaska, glengarry, sardinian,
# Nearest to d: represented, speeches, preterism, andamans, gastronomique, potato, bolted, motorcycles,
# Nearest to called: accordance, hamdi, righteousness, skinny, shootings, curitiba, gordie, recognizing,
# Nearest to something: strategy, konig, demigods, preferring, ivb, fished, uiuc, another,
# Nearest to units: chih, prespa, skenderbeg, traveller, scholz, anthologies, caesarion, budd,
# Nearest to question: burnham, aquifer, multicellular, unexpected, insecure, disarray, pluralized, teenage,
# Nearest to know: circulatory, brought, conectiva, wish, pilger, stanislaw, outcome, baglione,
# Nearest to channel: wootz, castile, precautions, nicklaus, lark, earthy, arsenio, tig,
# Nearest to primarily: conceptual, buttery, minarchist, atolls, ccp, gurmukhi, wrappings, moths,
# Nearest to file: gbu, stavropol, hazing, postmillennialism, refounded, lonely, moa, maclisp,
# Nearest to dr: gradus, magnetization, rables, presides, dada, nabba, etter, combs,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.5739 0.4573 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.4611 0.4361 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.4042 0.4496 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.3009 0.4590 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.2666 0.4389 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.2238 0.4412 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.1845 0.4366 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.1717 0.4283 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 5.0776 0.4397 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 5.0638 0.4396 sec/batch
# Nearest to th: joseph, fees, abstract, exploiting, galena, abrasives, pro, mash,
# Nearest to four: temporarily, commodity, jovis, atat, negative, five, pacifists, indoors,
# Nearest to american: anglican, sepsis, september, instance, suffocation, superior, consolidated, mckay,
# Nearest to may: mode, pesce, facilitate, risky, parents, scene, depicted, dropping,
# Nearest to nine: onboard, slava, generating, authors, hitting, presences, westminster, redskins,
# Nearest to an: contrabassoon, cro, glengarry, spencer, elisabeth, relay, leges, eyeglasses,
# Nearest to d: represented, speeches, motorcycles, gastronomique, potato, andamans, preterism, constitute,
# Nearest to called: accordance, righteousness, colleges, affirmed, recognizing, voice, hamdi, shootings,
# Nearest to something: strategy, preferring, another, demigods, uiuc, seaboard, ivb, notion,
# Nearest to units: patents, chih, tactics, scholz, skenderbeg, anthologies, composed, budd,
# Nearest to question: burnham, unexpected, teenage, lieutenant, multicellular, insecure, cedric, collected,
# Nearest to know: brought, wish, outcome, circulatory, pilger, conectiva, index, macroscopic,
# Nearest to channel: wootz, precautions, castile, earthy, yukio, etymology, hawkins, nicklaus,
# Nearest to primarily: conceptual, photograph, fell, atolls, gurmukhi, thoughts, moths, favors,
# Nearest to file: hazing, stavropol, underside, gbu, wonderland, lonely, acacias, refounded,
# Nearest to dr: gradus, rables, presides, borders, dada, nabba, magnetization, los,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9982 0.4429 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.9802 0.4344 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.9333 0.4319 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.9379 0.4324 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.9063 0.4323 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8646 0.4313 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.8411 0.4344 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.8493 0.4290 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.8575 0.4358 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.8415 0.4327 sec/batch
# Nearest to th: joseph, fees, abstract, exploiting, galena, rarest, abrasives, unsafe,
# Nearest to four: jovis, expounded, five, atat, pacifists, overlying, temporarily, conducts,
# Nearest to american: anglican, september, mckay, suffocation, haploid, sepsis, easter, superior,
# Nearest to may: mode, pesce, peasant, parents, facilitate, softened, silkworth, scene,
# Nearest to nine: onboard, slava, westminster, est, presences, redskins, one, hitting,
# Nearest to an: contrabassoon, cro, relay, eyeglasses, alaska, measurable, jurors, indiscriminate,
# Nearest to d: represented, speeches, potato, gastronomique, motorcycles, intimately, andamans, preterism,
# Nearest to called: accordance, righteousness, hamdi, shootings, affirmed, recognizing, voice, colleges,
# Nearest to something: preferring, strategy, another, demigods, fished, seaboard, uiuc, stimulated,
# Nearest to units: patents, chih, tactics, anthologies, traveller, composed, skenderbeg, scholz,
# Nearest to question: burnham, unexpected, insecure, teenage, lieutenant, multicellular, syracuse, cedric,
# Nearest to know: brought, wish, pilger, stanislaw, outcome, circulatory, incisive, rotten,
# Nearest to channel: precautions, wootz, castile, hawkins, etymology, coincidental, nicklaus, earthy,
# Nearest to primarily: conceptual, photograph, atolls, favors, thoughts, moths, guam, gurmukhi,
# Nearest to file: lonely, hazing, gbu, underside, stavropol, wonderland, acacias, elvis,
# Nearest to dr: gradus, rables, presides, borders, los, dada, magnetization, nabba,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.8188 0.4427 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.8171 0.4309 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7613 0.4354 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.7583 0.4322 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.8174 0.4291 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.7297 0.4320 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.7657 0.4309 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7709 0.4301 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.7575 0.4319 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6991 0.4367 sec/batch
# Nearest to th: joseph, fees, exploiting, galena, abstract, durables, sindhu, jessica,
# Nearest to four: five, jovis, expounded, kickboxer, overlying, atat, pee, est,
# Nearest to american: anglican, mckay, douard, sepsis, september, alexis, haploid, detract,
# Nearest to may: pesce, mode, peasant, softened, risky, nicolaus, gaussian, silkworth,
# Nearest to nine: slava, onboard, one, westminster, nobel, born, elector, est,
# Nearest to an: contrabassoon, cro, eyeglasses, jurors, indiscriminate, alaska, relay, measurable,
# Nearest to d: represented, speeches, potato, preterism, gastronomique, one, motorcycles, intimately,
# Nearest to called: righteousness, hamdi, accordance, lest, recognizing, affirmed, fer, confidently,
# Nearest to something: preferring, demigods, strategy, another, uiuc, fished, seaboard, stimulated,
# Nearest to units: patents, traveller, chih, tactics, anthologies, skenderbeg, discharge, scholz,
# Nearest to question: unexpected, burnham, insecure, teenage, cedric, gaza, syracuse, hamill,
# Nearest to know: pilger, baglione, wish, brought, stanislaw, incisive, outcome, rotten,
# Nearest to channel: wootz, precautions, hawkins, castile, nicklaus, yukio, mayhem, rebound,
# Nearest to primarily: conceptual, atolls, moths, photograph, thoughts, favors, fairest, wrappings,
# Nearest to file: gbu, hazing, stavropol, moa, maclisp, underside, elvis, wonderland,
# Nearest to dr: gradus, rables, presides, nabba, los, clarke, dada, magnetization,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.7063 0.4391 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.7132 0.4305 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6394 0.4275 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6921 0.4331 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6886 0.4280 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6854 0.4294 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.6022 0.3537 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5248 0.4796 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.5347 0.4485 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.5006 0.4564 sec/batch
# Nearest to th: joseph, durables, valle, inconsistently, exploiting, following, fees, siberia,
# Nearest to four: five, kickboxer, jovis, dramatist, pee, overlying, expounded, atat,
# Nearest to american: musician, mckay, douard, alexis, anglican, broadcaster, robert, haploid,
# Nearest to may: pesce, mode, softened, risky, peasant, durability, gaussian, nicolaus,
# Nearest to nine: nobel, one, slava, onboard, born, est, westminster, elector,
# Nearest to an: contrabassoon, eyeglasses, cro, indiscriminate, stallion, measurable, jurors, horrified,
# Nearest to d: one, speeches, preterism, rietveld, andamans, represented, robbie, champions,
# Nearest to called: fer, righteousness, confidently, hamdi, skinny, lest, voice, muds,
# Nearest to something: preferring, another, strategy, demigods, uiuc, fished, normality, pictured,
# Nearest to units: patents, skenderbeg, traveller, chih, tactics, prespa, anthologies, discharge,
# Nearest to question: burnham, multicellular, unexpected, hamill, pluralized, quantized, gaza, modernists,
# Nearest to know: baglione, pilger, wish, brought, stanislaw, myself, incisive, assessed,
# Nearest to channel: wootz, precautions, hawkins, yukio, nicklaus, castile, coincidental, mayhem,
# Nearest to primarily: conceptual, wrappings, atolls, minarchist, ccp, photograph, favors, quixote,
# Nearest to file: gbu, hazing, stavropol, moa, telco, maclisp, mistrust, wonderland,
# Nearest to dr: gradus, rables, presides, nabba, los, clarke, magnetization, welded,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.4962 0.4576 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.4949 0.4390 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4443 0.4443 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5122 0.4415 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.5021 0.4522 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4794 0.4529 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4334 0.4495 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.3541 0.4427 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4011 0.4433 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4149 0.4508 sec/batch
# Nearest to th: joseph, durables, tischendorf, exploiting, clairvaux, valle, galena, dover,
# Nearest to four: five, est, kickboxer, jovis, overlying, pee, zero, expounded,
# Nearest to american: mckay, alexis, haploid, suffocation, musician, reo, lifes, detract,
# Nearest to may: pesce, mode, softened, peasant, risky, gaussian, durability, mirc,
# Nearest to nine: slava, est, onboard, u, arena, westminster, elector, dakar,
# Nearest to an: contrabassoon, eyeglasses, indiscriminate, cro, measurable, stallion, jurors, horrified,
# Nearest to d: preterism, rietveld, gastronomique, lems, champions, andamans, represented, bolted,
# Nearest to called: skinny, fer, confidently, righteousness, hamdi, lest, rubra, diction,
# Nearest to something: preferring, strategy, another, demigods, konig, fished, uiuc, normality,
# Nearest to units: patents, skenderbeg, tactics, prespa, discharge, composed, chih, iole,
# Nearest to question: burnham, knowledgeable, multicellular, unexpected, pluralized, demonstrated, proof, transfinite,
# Nearest to know: baglione, wish, myself, brought, pilger, incisive, stanislaw, inwardly,
# Nearest to channel: wootz, hawkins, yukio, coincidental, arsenio, nicklaus, tackle, precautions,
# Nearest to primarily: conceptual, wrappings, ccp, minarchist, quixote, atolls, favors, moths,
# Nearest to file: telco, hazing, gbu, moa, underside, wonderland, stavropol, maclisp,
# Nearest to dr: gradus, rables, presides, nabba, los, clarke, magnetization, hara,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4355 0.4524 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.3905 0.4456 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4198 0.4402 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.3994 0.4434 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.3994 0.4521 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4245 0.4419 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3847 0.4457 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3550 0.4415 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.4107 0.4426 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3708 0.4423 sec/batch
# Nearest to th: joseph, durables, galena, clairvaux, tischendorf, exploiting, mutinied, following,
# Nearest to four: five, est, kickboxer, overlying, zero, jovis, expounded, pee,
# Nearest to american: mckay, alexis, musician, haploid, suffocation, douard, reo, lifes,
# Nearest to may: mode, pesce, durability, risky, gaussian, softened, peasant, mirc,
# Nearest to nine: est, slava, u, one, arena, westminster, nobel, unfalsifiable,
# Nearest to an: contrabassoon, cro, eyeglasses, stallion, indiscriminate, measurable, horrified, sombre,
# Nearest to d: gastronomique, rietveld, lems, preterism, chandler, potato, represented, nicolas,
# Nearest to called: skinny, hamdi, fer, confidently, righteousness, accordance, muds, lest,
# Nearest to something: preferring, strategy, demigods, another, uiuc, konig, fished, notion,
# Nearest to units: patents, skenderbeg, discharge, tactics, prespa, chih, iole, protista,
# Nearest to question: unexpected, knowledgeable, pluralized, multicellular, proof, transfinite, modernists, quantized,
# Nearest to know: baglione, wish, myself, brought, incisive, pilger, metropolises, stanislaw,
# Nearest to channel: wootz, hawkins, arsenio, yukio, nicklaus, mayhem, mfm, tackle,
# Nearest to primarily: conceptual, wrappings, quixote, favors, ccp, moths, minarchist, rar,
# Nearest to file: telco, underside, hazing, beams, arpanet, maclisp, gbu, wonderland,
# Nearest to dr: gradus, rables, los, nabba, presides, clarke, powell, hara,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3735 0.4495 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.3915 0.4594 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3278 0.4863 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3515 0.4506 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.3886 0.4488 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3616 0.4722 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.3548 0.4495 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3666 0.4447 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3169 0.4449 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3312 0.4425 sec/batch
# Nearest to th: exploiting, durables, mash, joseph, galena, tischendorf, elsewhere, clairvaux,
# Nearest to four: five, est, zero, two, three, kickboxer, overlying, jovis,
# Nearest to american: alexis, mckay, suffocation, installment, haploid, lifes, reo, detract,
# Nearest to may: mode, pesce, durability, risky, mirc, softened, peasant, gaussian,
# Nearest to nine: est, slava, one, u, unfalsifiable, three, arena, westminster,
# Nearest to an: contrabassoon, eyeglasses, cro, indiscriminate, stallion, alaska, diverge, oversized,
# Nearest to d: preterism, gastronomique, rietveld, represented, lems, potato, chandler, bolted,
# Nearest to called: skinny, hamdi, poudre, accordance, righteousness, fer, ronan, confidently,
# Nearest to something: preferring, demigods, another, uiuc, strategy, konig, fished, admits,
# Nearest to units: patents, skenderbeg, prespa, discharge, tactics, iole, chih, traveller,
# Nearest to question: proof, unexpected, transfinite, modernists, knowledgeable, hamill, pluralized, syracuse,
# Nearest to know: baglione, myself, wish, pilger, incisive, brought, inwardly, metropolises,
# Nearest to channel: wootz, arsenio, mfm, hawkins, tackle, mayhem, coincidental, nicklaus,
# Nearest to primarily: quixote, favors, wrappings, conceptual, ccp, rar, atolls, minarchist,
# Nearest to file: telco, maclisp, hazing, gbu, arpanet, underside, prototyping, network,
# Nearest to dr: gradus, rables, nabba, los, combs, magnetization, clarke, presides,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3385 0.4549 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.2995 0.4449 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3269 0.4487 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3870 0.4459 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.3815 0.4439 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.2726 0.4449 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.3095 0.4467 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3265 0.4632 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2272 0.4443 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.2923 0.4620 sec/batch
# Nearest to th: durables, exploiting, tischendorf, clairvaux, mash, joseph, froissart, mutinied,
# Nearest to four: five, zero, two, est, three, kickboxer, dollar, jovis,
# Nearest to american: alexis, mckay, musician, andre, reo, broadcaster, douard, installment,
# Nearest to may: pesce, mode, risky, durability, mirc, softened, dropping, overestimated,
# Nearest to nine: one, est, u, slava, zero, nobel, two, three,
# Nearest to an: contrabassoon, eyeglasses, indiscriminate, cro, alaska, oversized, stallion, eschewing,
# Nearest to d: rietveld, gastronomique, nellie, nicolas, robbie, angli, khayy, chandler,
# Nearest to called: skinny, poudre, fer, righteousness, hamdi, accordance, gooch, confidently,
# Nearest to something: preferring, demigods, another, strategy, uiuc, fished, konig, drm,
# Nearest to units: patents, prespa, discharge, skenderbeg, tactics, iole, thermodynamic, traveller,
# Nearest to question: proof, transfinite, unexpected, knowledgeable, pluralized, syracuse, carchemish, insecure,
# Nearest to know: myself, wish, baglione, pilger, incisive, brought, you, inwardly,
# Nearest to channel: wootz, arsenio, hawkins, mfm, yukio, tackle, nicklaus, earthy,
# Nearest to primarily: quixote, wrappings, favors, minarchist, ccp, buttery, conceptual, atolls,
# Nearest to file: maclisp, telco, hazing, gbu, underside, arpanet, viacom, webpage,
# Nearest to dr: gradus, rables, nabba, powell, los, clarke, presides, combs,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.3076 0.4575 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.2739 0.4460 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3358 0.1960 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2076 0.4552 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2053 0.4506 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.1837 0.4476 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.2052 0.4431 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.1907 0.4408 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.1993 0.4418 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1119 0.4480 sec/batch
# Nearest to th: durables, elsewhere, exploiting, clairvaux, tischendorf, following, largest, froissart,
# Nearest to four: five, zero, three, two, est, kickboxer, six, jovis,
# Nearest to american: alexis, mckay, musician, reo, muzorewa, surname, reggaeton, installment,
# Nearest to may: pesce, mode, risky, durability, softened, peasant, dropping, mirc,
# Nearest to nine: one, est, slava, u, zero, three, endogamy, arena,
# Nearest to an: contrabassoon, cro, eyeglasses, indiscriminate, alaska, oversized, stallion, cub,
# Nearest to d: rietveld, gastronomique, angli, khayy, neuroscientist, nellie, robbie, represented,
# Nearest to called: poudre, skinny, accordance, fer, hamdi, wild, rubra, gooch,
# Nearest to something: preferring, demigods, uiuc, another, konig, drm, hellish, strategy,
# Nearest to units: patents, tactics, prespa, discharge, skenderbeg, targeting, outlining, metre,
# Nearest to question: proof, transfinite, unexpected, syracuse, quantized, pluralized, knowledgeable, modernists,
# Nearest to know: myself, baglione, wish, pilger, incisive, brought, you, inwardly,
# Nearest to channel: wootz, hawkins, mfm, tackle, arsenio, yukio, licence, coincidental,
# Nearest to primarily: quixote, buttery, wrappings, ccp, rar, favors, minarchist, atolls,
# Nearest to file: maclisp, telco, underside, webpage, gbu, hazing, viacom, arpanet,
# Nearest to dr: gradus, rables, nabba, clarke, los, inspirations, powell, magnetization,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2325 0.4577 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.1935 0.4393 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.1907 0.4414 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1046 0.4451 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1335 0.4435 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1171 0.5576 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1518 0.4881 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1475 0.4520 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.1877 0.4302 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1688 0.4283 sec/batch
# Nearest to th: tischendorf, durables, clairvaux, exploiting, elsewhere, froissart, mash, anniversary,
# Nearest to four: five, zero, two, three, est, six, kickboxer, mph,
# Nearest to american: alexis, thirsty, haploid, brancusi, surname, muzorewa, instance, reo,
# Nearest to may: mode, pesce, risky, durability, softened, dropping, peasant, mirc,
# Nearest to nine: one, zero, est, u, slava, three, dakar, endogamy,
# Nearest to an: contrabassoon, cro, eyeglasses, indiscriminate, cub, alaska, oversized, clarification,
# Nearest to d: rietveld, khayy, angli, gastronomique, represented, bolted, nellie, andamans,
# Nearest to called: poudre, skinny, accordance, righteousness, fer, gooch, rubra, hamdi,
# Nearest to something: preferring, uiuc, demigods, hellish, another, konig, drm, fished,
# Nearest to units: patents, tactics, prespa, discharge, skenderbeg, targeting, iole, metre,
# Nearest to question: proof, transfinite, unexpected, pluralized, syracuse, insecure, quantized, oxidizes,
# Nearest to know: myself, wish, baglione, pilger, inwardly, incisive, brought, you,
# Nearest to channel: hawkins, wootz, mfm, arsenio, licence, mayhem, tackle, scatter,
# Nearest to primarily: quixote, buttery, wrappings, ccp, rar, favors, moths, atolls,
# Nearest to file: maclisp, telco, underside, hazing, multilingual, webpage, viacom, chessgames,
# Nearest to dr: gradus, rables, powell, nabba, clarke, inspirations, magnetization, combs,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1502 0.4429 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.1630 0.4351 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1252 0.4888 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1300 0.5334 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1468 0.6645 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.1409 0.5537 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.1827 0.4593 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1193 0.5494 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1249 0.5217 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1503 0.4937 sec/batch
# Nearest to th: clairvaux, exploiting, durables, froissart, tischendorf, mutinied, mash, anniversary,
# Nearest to four: five, zero, two, three, est, six, kickboxer, one,
# Nearest to american: alexis, brancusi, muzorewa, indian, asch, thirsty, lenny, instance,
# Nearest to may: pesce, mode, risky, durability, dropping, triiodothyronine, mirc, peasant,
# Nearest to nine: one, zero, est, three, slava, u, two, rate,
# Nearest to an: contrabassoon, cro, eyeglasses, oversized, alaska, cub, stallion, indiscriminate,
# Nearest to d: rietveld, khayy, gastronomique, angli, neuroscientist, nellie, represented, robbie,
# Nearest to called: poudre, skinny, gooch, fer, accordance, cliches, righteousness, postings,
# Nearest to something: preferring, uiuc, another, demigods, hellish, pictured, idiosyncrasies, konig,
# Nearest to units: patents, tactics, prespa, metre, targeting, discharge, skenderbeg, chih,
# Nearest to question: proof, unexpected, syracuse, transfinite, insecure, modernists, quantized, subsequent,
# Nearest to know: myself, wish, baglione, pilger, you, brought, inwardly, don,
# Nearest to channel: wootz, hawkins, arsenio, mfm, licence, scatter, mayhem, daytona,
# Nearest to primarily: quixote, buttery, wrappings, ccp, favors, boka, rar, conceptual,
# Nearest to file: maclisp, underside, telco, multilingual, hazing, gbu, viacom, rot,
# Nearest to dr: gradus, rables, powell, nabba, inspirations, combs, clarke, attaining,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.1619 0.5338 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1464 0.5547 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1288 0.5031 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.1642 0.5155 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1399 0.5477 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1022 0.5138 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1383 0.6416 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1298 0.5804 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.1735 0.4999 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.1935 0.5361 sec/batch
# Nearest to th: century, clairvaux, mutinied, gatherers, durables, elsewhere, exploiting, froissart,
# Nearest to four: five, two, zero, three, six, est, one, seven,
# Nearest to american: alexis, musician, muzorewa, brancusi, lenny, indian, andre, triathlon,
# Nearest to may: mode, pesce, risky, dropping, durability, globemaster, triiodothyronine, buprenorphine,
# Nearest to nine: one, zero, slava, three, est, two, six, u,
# Nearest to an: contrabassoon, eyeglasses, indiscriminate, alaska, the, cro, oversized, cub,
# Nearest to d: rietveld, neuroscientist, gastronomique, khayy, nellie, angli, bernhard, robbie,
# Nearest to called: poudre, skinny, righteousness, fer, accordance, cliches, gooch, postings,
# Nearest to something: preferring, hellish, uiuc, demigods, idiosyncrasies, konig, another, pictured,
# Nearest to units: patents, tactics, prespa, metre, skenderbeg, targeting, discharge, iole,
# Nearest to question: proof, syracuse, transfinite, modernists, insecure, quantized, unexpected, lieutenant,
# Nearest to know: myself, wish, pilger, you, baglione, brought, inwardly, incisive,
# Nearest to channel: wootz, hawkins, scatter, mfm, arsenio, licence, mayhem, daytona,
# Nearest to primarily: quixote, buttery, ccp, wrappings, conceptual, century, favors, boka,
# Nearest to file: maclisp, telco, underside, rot, hazing, prototyping, stavropol, gbu,
# Nearest to dr: gradus, rables, nabba, powell, combs, inspirations, clarke, attaining,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.1907 0.6067 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.0866 0.4855 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1107 0.4937 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1322 0.4907 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0021 0.4891 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.0963 0.6132 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1186 0.4858 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1012 0.4679 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1409 0.0704 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.0723 0.4342 sec/batch
# Nearest to th: durables, century, clairvaux, anniversary, exploiting, gatherers, elsewhere, mutinied,
# Nearest to four: five, two, zero, three, est, six, one, seven,
# Nearest to american: alexis, brancusi, muzorewa, weizenbaum, indian, instance, thirsty, triathlon,
# Nearest to may: pesce, mode, triiodothyronine, dropping, risky, durability, tla, mirc,
# Nearest to nine: one, zero, three, two, est, slava, u, six,
# Nearest to an: contrabassoon, oversized, cro, alaska, cub, eyeglasses, indiscriminate, clarification,
# Nearest to d: rietveld, gastronomique, khayy, neuroscientist, angli, bernhard, nellie, belgium,
# Nearest to called: poudre, skinny, gooch, fer, cliches, accordance, intensities, pot,
# Nearest to something: preferring, idiosyncrasies, hellish, uiuc, konig, pictured, demigods, backs,
# Nearest to units: tactics, patents, metre, prespa, skenderbeg, discharge, targeting, chih,
# Nearest to question: proof, syracuse, insecure, quantized, transfinite, unexpected, lieutenant, modernists,
# Nearest to know: myself, wish, pilger, baglione, you, inwardly, brought, outcome,
# Nearest to channel: wootz, scatter, hawkins, mfm, arsenio, licence, daytona, mayhem,
# Nearest to primarily: quixote, buttery, wrappings, ccp, conceptual, moths, century, rar,
# Nearest to file: maclisp, telco, rot, underside, prototyping, viacom, stavropol, hazing,
# Nearest to dr: gradus, rables, nabba, powell, combs, inspirations, attaining, accreditation,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0644 0.5334 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0267 0.5067 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.0807 0.4729 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0164 0.5954 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0402 0.6172 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0056 0.4620 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.0476 0.4667 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.0789 0.4711 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.0614 0.5059 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 3.9843 0.5464 sec/batch
# Nearest to th: century, anniversary, clairvaux, durables, elsewhere, gatherers, exploiting, froissart,
# Nearest to four: five, two, zero, three, six, est, one, seven,
# Nearest to american: instance, alexis, brancusi, weizenbaum, thirsty, muzorewa, lifes, indian,
# Nearest to may: mode, pesce, risky, triiodothyronine, dropping, durability, rarely, mirc,
# Nearest to nine: one, zero, est, three, slava, two, rate, six,
# Nearest to an: contrabassoon, cro, oversized, alaska, cub, indiscriminate, eyeglasses, clarification,
# Nearest to d: rietveld, khayy, gastronomique, angli, neuroscientist, represented, belgium, grotius,
# Nearest to called: poudre, skinny, accordance, pot, intensities, wild, fer, gooch,
# Nearest to something: preferring, idiosyncrasies, hellish, uiuc, backs, another, konig, fished,
# Nearest to units: tactics, metre, patents, prespa, targeting, skenderbeg, iole, discharge,
# Nearest to question: syracuse, proof, insecure, transfinite, quantized, unexpected, lieutenant, modernists,
# Nearest to know: myself, wish, you, pilger, baglione, inwardly, brought, outcome,
# Nearest to channel: wootz, hawkins, arsenio, scatter, mfm, licence, coincidental, daytona,
# Nearest to primarily: quixote, buttery, wrappings, moths, conceptual, ccp, century, arrondissement,
# Nearest to file: maclisp, telco, hazing, underside, stavropol, chessgames, rot, viacom,
# Nearest to dr: rables, gradus, nabba, combs, inspirations, powell, clarke, attaining,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 3.9955 0.5438 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 3.9976 0.5286 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 3.9885 0.4787 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0266 0.5316 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0479 0.5222 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0000 0.5784 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0144 0.5092 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.0773 0.4639 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 3.9982 0.4963 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0137 0.5457 sec/batch
# Nearest to th: anniversary, clairvaux, century, froissart, exploiting, durables, gatherers, elsewhere,
# Nearest to four: five, two, three, zero, est, six, one, seven,
# Nearest to american: alexis, instance, brancusi, thirsty, weizenbaum, lifes, muzorewa, gender,
# Nearest to may: pesce, mode, risky, dropping, durability, legitimacy, triiodothyronine, buprenorphine,
# Nearest to nine: one, zero, three, est, slava, two, four, rate,
# Nearest to an: contrabassoon, cro, oversized, clarification, eyeglasses, cub, desired, inductance,
# Nearest to d: khayy, rietveld, gastronomique, angli, belgium, bernhard, represented, neuroscientist,
# Nearest to called: poudre, skinny, cliches, gooch, accordance, prophetically, finitely, fer,
# Nearest to something: preferring, idiosyncrasies, hellish, konig, backs, uiuc, another, vso,
# Nearest to units: metre, patents, prespa, tactics, targeting, skenderbeg, si, chih,
# Nearest to question: syracuse, insecure, proof, transfinite, quantized, unexpected, oxidizes, lieutenant,
# Nearest to know: myself, wish, you, pilger, inwardly, baglione, don, brought,
# Nearest to channel: wootz, hawkins, arsenio, scatter, coincidental, licence, mfm, etymology,
# Nearest to primarily: quixote, buttery, conceptual, ccp, moths, arrondissement, wrappings, their,
# Nearest to file: maclisp, hazing, autonegotiation, stavropol, underside, viacom, rot, chessgames,
# Nearest to dr: rables, gradus, nabba, accreditation, clarke, combs, inspirations, attaining,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0343 0.5365 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0497 0.5407 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0268 0.5195 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0186 0.5259 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0189 0.5050 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0088 0.4814 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0447 0.5701 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0274 0.5466 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.0613 0.5509 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0261 0.4663 sec/batch
# Nearest to th: century, gatherers, clairvaux, anniversary, exploiting, elsewhere, gregorian, froissart,
# Nearest to four: five, two, three, zero, six, est, one, seven,
# Nearest to american: instance, alexis, brancusi, gender, aai, weizenbaum, lifes, triathlon,
# Nearest to may: pesce, mode, dropping, risky, legitimacy, durability, globemaster, buprenorphine,
# Nearest to nine: one, zero, est, three, two, slava, four, rate,
# Nearest to an: contrabassoon, cub, cro, the, alaska, injustices, eyeglasses, clarification,
# Nearest to d: khayy, rietveld, gastronomique, angli, belgium, nellie, grotius, neuroscientist,
# Nearest to called: poudre, skinny, accordance, prophetically, gooch, fer, postings, vegas,
# Nearest to something: preferring, hellish, idiosyncrasies, konig, backs, defenders, uiuc, fished,
# Nearest to units: metre, prespa, patents, tactics, targeting, skenderbeg, si, heiner,
# Nearest to question: syracuse, insecure, lieutenant, unexpected, transfinite, proof, quantized, hamill,
# Nearest to know: myself, you, wish, pilger, inwardly, baglione, don, lumberjack,
# Nearest to channel: wootz, hawkins, arsenio, licence, tig, coincidental, scatter, preconceived,
# Nearest to primarily: quixote, buttery, conceptual, ccp, their, arrondissement, wrappings, moths,
# Nearest to file: maclisp, hazing, postmillennialism, prototyping, viacom, webring, stavropol, autonegotiation,
# Nearest to dr: rables, gradus, nabba, attaining, accreditation, combs, los, inspirations,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0237 0.5491 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 3.9880 0.5020 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0092 0.5282 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0083 0.5367 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0460 0.5416 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.0826 0.5217 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.0856 0.4547 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 3.9969 0.5053 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 3.9842 0.4531 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0308 0.4360 sec/batch
# Nearest to th: century, anniversary, clairvaux, gatherers, elsewhere, mutinied, exploiting, durables,
# Nearest to four: five, two, zero, three, one, six, seven, est,
# Nearest to american: alexis, brancusi, instance, weizenbaum, lifes, triathlon, musician, aai,
# Nearest to may: mode, pesce, dropping, risky, triiodothyronine, globemaster, legitimacy, durability,
# Nearest to nine: one, zero, three, slava, two, est, four, six,
# Nearest to an: the, contrabassoon, cub, clarification, cro, indiscriminate, alaska, oversized,
# Nearest to d: rietveld, khayy, gastronomique, angli, nellie, belgium, bernhard, grotius,
# Nearest to called: poudre, postings, cliches, accordance, skinny, gooch, vegas, prophetically,
# Nearest to something: preferring, hellish, idiosyncrasies, another, backs, konig, uiuc, fished,
# Nearest to units: metre, prespa, patents, tactics, si, targeting, skenderbeg, chih,
# Nearest to question: syracuse, insecure, quantized, transfinite, proof, lieutenant, unexpected, laureates,
# Nearest to know: myself, pilger, wish, you, don, inwardly, brought, baglione,
# Nearest to channel: wootz, hawkins, scatter, preconceived, tig, licence, mfm, telnet,
# Nearest to primarily: quixote, buttery, moths, ccp, century, conceptual, arrondissement, wrappings,
# Nearest to file: maclisp, hazing, prototyping, rot, autonegotiation, webring, postmillennialism, telco,
# Nearest to dr: rables, gradus, nabba, accreditation, attaining, inspirations, combs, los,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.9431 0.4358 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 4.0086 0.4252 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 3.9974 0.4294 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0070 0.4257 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0377 0.4289 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0105 0.4131 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 3.9471 36.9510 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9432 0.4487 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 3.9811 0.4383 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9227 0.4398 sec/batch
# Nearest to th: century, anniversary, clairvaux, gregorian, rd, gatherers, durables, elsewhere,
# Nearest to four: five, two, three, zero, one, six, seven, nine,
# Nearest to american: brancusi, alexis, instance, musician, lenny, lifes, discreet, triathlon,
# Nearest to may: dropping, mode, pesce, legitimacy, default, hypoglycemic, triiodothyronine, risky,
# Nearest to nine: one, zero, three, two, slava, four, six, est,
# Nearest to an: cro, contrabassoon, cub, indiscriminate, the, injustices, oversized, cvbg,
# Nearest to d: rietveld, khayy, gastronomique, belgium, angli, barfield, nellie, grotius,
# Nearest to called: poudre, accordance, survives, prophetically, postings, tautologies, skinny, fer,
# Nearest to something: preferring, hellish, idiosyncrasies, backs, another, uiuc, konig, fished,
# Nearest to units: metre, prespa, patents, si, tactics, targeting, skenderbeg, chih,
# Nearest to question: syracuse, transfinite, insecure, quantized, proof, lieutenant, unexpected, oxidizes,
# Nearest to know: myself, you, wish, pilger, inwardly, brought, don, baglione,
# Nearest to channel: wootz, hawkins, scatter, tig, univision, licence, atlantic, arsenio,
# Nearest to primarily: quixote, buttery, ccp, their, arrondissement, moths, conceptual, favors,
# Nearest to file: maclisp, rot, hazing, postmillennialism, viacom, autonegotiation, prototyping, webring,
# Nearest to dr: rables, gradus, nabba, accreditation, attaining, inspirations, los, transgender,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 3.9610 0.4473 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9163 0.4302 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 3.9634 0.4330 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 3.9885 0.4414 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 3.9506 0.4401 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 3.9281 0.4394 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.8649 0.4336 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9165 0.4350 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.8730 0.4305 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9178 0.4371 sec/batch
# Nearest to th: century, anniversary, clairvaux, froissart, gatherers, gregorian, elsewhere, rd,
# Nearest to four: five, two, three, zero, six, one, seven, nine,
# Nearest to american: instance, brancusi, discreet, bunyips, sherry, alexis, thirsty, lenny,
# Nearest to may: dropping, mode, pesce, hypoglycemic, legitimacy, risky, buprenorphine, rarely,
# Nearest to nine: one, zero, three, two, four, six, slava, est,
# Nearest to an: cro, contrabassoon, oversized, cub, inductance, clarification, cvbg, the,
# Nearest to d: rietveld, khayy, gastronomique, andamans, bolted, angli, unoccupied, belgium,
# Nearest to called: poudre, accordance, postings, skinny, pot, survives, prophetically, finitely,
# Nearest to something: preferring, hellish, idiosyncrasies, another, fished, backs, uiuc, chechnya,
# Nearest to units: metre, prespa, tactics, patents, si, targeting, skenderbeg, chih,
# Nearest to question: syracuse, transfinite, proof, insecure, quantized, lieutenant, unexpected, laureates,
# Nearest to know: myself, you, wish, inwardly, don, pilger, brought, baglione,
# Nearest to channel: wootz, hawkins, scatter, licence, univision, tig, coincidental, atlantic,
# Nearest to primarily: buttery, quixote, their, moths, conceptual, ccp, favors, wrappings,
# Nearest to file: maclisp, postmillennialism, hazing, viacom, rot, autonegotiation, chessgames, diskette,
# Nearest to dr: rables, gradus, nabba, accreditation, attaining, unanimity, inspirations, combs,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 3.9582 0.4456 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 3.9624 0.4338 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9203 0.4331 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 3.9803 0.4348 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 3.9557 0.4329 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9018 0.4312 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 3.9575 0.4542 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 3.9474 0.4344 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 3.9451 0.4452 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 3.9564 0.4445 sec/batch
# Nearest to th: century, anniversary, clairvaux, gregorian, froissart, gatherers, rd, centuries,
# Nearest to four: five, two, three, zero, one, six, seven, nine,
# Nearest to american: musician, brancusi, lenny, indian, alexis, asch, melvyn, muzorewa,
# Nearest to may: dropping, pesce, legitimacy, hypoglycemic, rarely, globemaster, risky, buprenorphine,
# Nearest to nine: one, zero, three, two, four, five, six, seven,
# Nearest to an: contrabassoon, cro, cub, oversized, inductance, clarification, cvbg, the,
# Nearest to d: rietveld, khayy, gastronomique, angli, nellie, grotius, barfield, andamans,
# Nearest to called: poudre, postings, cliches, prophetically, skinny, tautologies, gooch, accordance,
# Nearest to something: preferring, hellish, idiosyncrasies, fished, uiuc, another, subjectivism, konig,
# Nearest to units: metre, prespa, tactics, si, targeting, patents, skenderbeg, geocaches,
# Nearest to question: syracuse, insecure, transfinite, quantized, unexpected, proof, lieutenant, answer,
# Nearest to know: myself, you, don, wish, pilger, inwardly, brought, i,
# Nearest to channel: wootz, hawkins, univision, licence, scatter, tig, atlantic, fluent,
# Nearest to primarily: quixote, buttery, ccp, their, conceptual, moths, arrondissement, rar,
# Nearest to file: maclisp, rot, viacom, webring, postmillennialism, chessgames, autonegotiation, hazing,
# Nearest to dr: rables, accreditation, gradus, nabba, attaining, combs, transgender, inspirations,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 3.9515 0.4487 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.9870 0.4355 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.9526 0.4314 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 3.9845 0.4401 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 3.9517 0.4388 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 3.9677 0.4374 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.9505 0.4352 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9588 0.4362 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9161 0.4335 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 3.9756 0.4377 sec/batch
# Nearest to th: century, anniversary, gatherers, centuries, gregorian, clairvaux, froissart, late,
# Nearest to four: five, two, three, zero, one, six, seven, nine,
# Nearest to american: brancusi, alexis, instance, lenny, sherry, discreet, weizenbaum, thirsty,
# Nearest to may: dropping, legitimacy, mode, pesce, risky, default, rarely, globemaster,
# Nearest to nine: one, zero, three, two, four, six, five, seven,
# Nearest to an: cro, the, inductance, contrabassoon, cvbg, clarification, alaska, injustices,
# Nearest to d: rietveld, khayy, gastronomique, angli, andamans, nellie, barfield, belgium,
# Nearest to called: poudre, postings, prophetically, tautologies, accordance, survives, finitely, skinny,
# Nearest to something: preferring, hellish, idiosyncrasies, uiuc, fished, konig, amarant, subjectivism,
# Nearest to units: metre, prespa, si, tactics, patents, targeting, skenderbeg, heiner,
# Nearest to question: syracuse, insecure, transfinite, unexpected, lieutenant, proof, answer, quantized,
# Nearest to know: myself, you, don, wish, pilger, brought, inwardly, indications,
# Nearest to channel: wootz, univision, tig, hawkins, scatter, licence, atlantic, arsenio,
# Nearest to primarily: buttery, quixote, ccp, their, moths, boka, arrondissement, century,
# Nearest to file: maclisp, postmillennialism, rot, canso, ceremonies, autonegotiation, hazing, chessgames,
# Nearest to dr: rables, accreditation, gradus, nabba, attaining, combs, los, antiseptic,
# Epoch 5/10 Iteration: 22100 Avg. Training loss: 3.9409 0.4500 sec/batch
# Epoch 5/10 Iteration: 22200 Avg. Training loss: 4.0607 0.4359 sec/batch
# Epoch 5/10 Iteration: 22300 Avg. Training loss: 3.9832 0.4352 sec/batch
# Epoch 5/10 Iteration: 22400 Avg. Training loss: 4.0199 0.4304 sec/batch
# Epoch 5/10 Iteration: 22500 Avg. Training loss: 3.8942 0.4309 sec/batch
# ...
# Nearest to th: century, anniversary, rd, centuries, gregorian, clairvaux, hants, eleventh,
# Nearest to four: five, two, one, seven, zero, six, three, nine,
# Nearest to american: sherry, melvyn, selectively, discreet, alexis, qantas, lenny, tlingit,
# Nearest to may: be, rarely, or, buprenorphine, risky, hypoglycemic, day, rules,
# Nearest to nine: one, zero, two, six, four, three, five, seven,
# Nearest to an: a, the, of, or, whose, skate, contrabassoon, in,
# Nearest to d: rietveld, khayy, gastronomique, grotius, angli, osgood, successors, licensed,
# Nearest to called: the, a, in, postings, which, other, poudre, but,
# Nearest to something: preferring, hellish, pike, centigrade, stimulated, fished, distributions, coughing,
# Nearest to units: si, prespa, metre, makeup, targeting, unit, fortify, skenderbeg,
# Nearest to question: syracuse, answer, economist, insecure, brugge, hideki, quantized, ithaca,
# Nearest to know: wish, myself, i, you, don, want, extradition, brought,
# Nearest to channel: wootz, univision, channels, licence, tig, eurosceptics, atlantic, headland,
# Nearest to primarily: their, quixote, buttery, of, moths, arrondissement, announcements, mancha,
# Nearest to file: canso, maclisp, wandering, autonegotiation, viacom, drukqs, brushing, chessgames,
# Nearest to dr: attaining, accreditation, underway, antiseptic, morrill, rables, rushton, nabba,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.7973 0.4331 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8018 0.4251 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.8415 0.4270 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8144 0.4216 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.8010 0.4264 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.8564 0.4296 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.8165 0.4285 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.7830 0.4296 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.8305 0.4437 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.7941 0.4301 sec/batch
# Nearest to th: century, anniversary, centuries, rd, gregorian, modern, clairvaux, eleventh,
# Nearest to four: two, five, one, seven, zero, six, three, nine,
# Nearest to american: selectively, sherry, discreet, alexis, melvyn, tlingit, qantas, civilizations,
# Nearest to may: be, rarely, or, buprenorphine, risky, day, commemoration, hypoglycemic,
# Nearest to nine: one, zero, two, three, four, six, eight, five,
# Nearest to an: a, the, of, whose, or, skate, inductance, is,
# Nearest to d: khayy, rietveld, successors, gastronomique, licensed, grotius, potato, angli,
# Nearest to called: in, postings, the, which, a, other, but, poudre,
# Nearest to something: preferring, hellish, pike, stimulated, fished, centigrade, coughing, chatting,
# Nearest to units: si, prespa, metre, targeting, makeup, fortify, tactics, skenderbeg,
# Nearest to question: syracuse, answer, insecure, hideki, brugge, economist, quantized, ithaca,
# Nearest to know: i, wish, myself, you, don, brought, xyzzy, want,
# Nearest to channel: wootz, univision, channels, tig, eurosceptics, licence, headland, atlantic,
# Nearest to primarily: their, quixote, buttery, of, arrondissement, conceptual, as, moths,
# Nearest to file: canso, wandering, maclisp, autonegotiation, viacom, drukqs, coloureds, chessgames,
# Nearest to dr: attaining, accreditation, rables, nabba, underway, antiseptic, rushton, morrill,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.8264 0.4391 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.8481 0.4221 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.8069 0.4225 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.7986 0.4257 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.8729 0.4237 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.8241 0.4287 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9103 0.4275 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.8555 0.4227 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.8871 0.4244 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.7670 0.4245 sec/batch
# Nearest to th: century, centuries, anniversary, gregorian, rd, eleventh, modern, gatherers,
# Nearest to four: two, five, one, seven, zero, three, six, nine,
# Nearest to american: selectively, sherry, alexis, melvyn, freedom, discreet, weizenbaum, canadian,
# Nearest to may: be, rarely, or, risky, day, buprenorphine, commemoration, although,
# Nearest to nine: one, zero, two, four, six, three, five, eight,
# Nearest to an: a, the, of, or, skate, whose, external, in,
# Nearest to d: rietveld, khayy, angli, grotius, gastronomique, cloves, osgood, assembl,
# Nearest to called: postings, poudre, in, the, other, which, a, also,
# Nearest to something: preferring, hellish, pike, stimulated, fished, coughing, chatting, distributions,
# Nearest to units: si, prespa, metre, fortify, makeup, tactics, skenderbeg, targeting,
# Nearest to question: answer, syracuse, insecure, hideki, economist, brugge, quantized, ithaca,
# Nearest to know: wish, you, i, myself, don, extradition, xyzzy, want,
# Nearest to channel: wootz, univision, channels, eurosceptics, tig, atlantic, licence, headland,
# Nearest to primarily: their, buttery, quixote, of, sealift, moths, flowed, arrondissement,
# Nearest to file: canso, wandering, maclisp, autonegotiation, drukqs, viacom, ahmad, coloureds,
# Nearest to dr: attaining, accreditation, underway, antiseptic, rables, rushton, morrill, nabba,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.7503 0.4309 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.8317 0.4183 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.7113 0.4281 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.8197 0.4237 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.8084 0.4264 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.7840 0.4277 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.8796 0.2035 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.7687 0.4297 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.7927 0.4264 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8160 0.4266 sec/batch
# Nearest to th: century, anniversary, centuries, gregorian, rd, eleventh, hants, clairvaux,
# Nearest to four: five, two, one, seven, six, three, zero, nine,
# Nearest to american: sherry, alexis, selectively, melvyn, psychotherapist, weizenbaum, canadian, freedom,
# Nearest to may: be, day, buprenorphine, or, rarely, risky, commemoration, antipsychotics,
# Nearest to nine: one, zero, four, six, two, five, eight, three,
# Nearest to an: a, the, of, skate, or, whose, is, external,
# Nearest to d: rietveld, khayy, osgood, grotius, gastronomique, wolfowitz, potato, mbox,
# Nearest to called: postings, in, poudre, the, a, which, other, it,
# Nearest to something: pike, hellish, preferring, stimulated, distributions, fished, chatting, lusthog,
# Nearest to units: si, metre, prespa, makeup, fortify, unit, skenderbeg, redefined,
# Nearest to question: answer, syracuse, insecure, hideki, brugge, economist, quantized, aumann,
# Nearest to know: you, wish, i, myself, want, xyzzy, don, extradition,
# Nearest to channel: wootz, univision, channels, atlantic, eurosceptics, tig, headland, shangchuan,
# Nearest to primarily: their, quixote, buttery, moths, of, caen, arrondissement, mancha,
# Nearest to file: canso, maclisp, wandering, autonegotiation, viacom, drukqs, chessgames, ahmad,
# Nearest to dr: attaining, antiseptic, underway, accreditation, rushton, rables, nabba, morrill,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.7919 0.4462 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.7801 0.4180 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.7956 0.4245 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.7414 0.4226 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.8193 0.4252 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.7770 0.4186 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.8109 0.4264 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.7042 0.4251 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.7491 0.4401 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.7559 0.4205 sec/batch
# Nearest to th: century, anniversary, centuries, rd, gregorian, eleventh, modern, hants,
# Nearest to four: five, two, one, seven, three, six, zero, nine,
# Nearest to american: selectively, alexis, sherry, freedom, melvyn, qantas, psychotherapist, weizenbaum,
# Nearest to may: be, or, day, buprenorphine, is, risky, rarely, dissolves,
# Nearest to nine: one, zero, six, four, two, five, three, eight,
# Nearest to an: a, the, of, is, or, whose, for, to,
# Nearest to d: khayy, rietveld, mbox, grotius, osgood, mathbb, potato, andamans,
# Nearest to called: in, postings, the, which, poudre, other, it, a,
# Nearest to something: hellish, preferring, pike, chatting, stimulated, keeping, fished, distributions,
# Nearest to units: si, metre, prespa, makeup, fortify, unit, skenderbeg, targeting,
# Nearest to question: answer, syracuse, hideki, insecure, brugge, economist, duhem, answers,
# Nearest to know: you, i, wish, myself, want, xyzzy, don, promulgation,
# Nearest to channel: wootz, univision, channels, eurosceptics, atlantic, licence, tig, headland,
# Nearest to primarily: their, of, buttery, quixote, moths, as, flowed, arrondissement,
# Nearest to file: canso, wandering, maclisp, viacom, drukqs, autonegotiation, laine, coloureds,
# Nearest to dr: attaining, accreditation, antiseptic, underway, rushton, nabba, rables, acrylics,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.6995 0.4280 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.7794 0.4598 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.8293 27.8737 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.7991 0.4840 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.7593 0.4214 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.8145 0.4251 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.7891 0.4244 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.7511 0.4242 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.7633 0.4202 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.7773 0.4242 sec/batch
# Nearest to th: century, anniversary, centuries, rd, gregorian, eleventh, hants, modern,
# Nearest to four: five, two, one, seven, three, six, zero, nine,
# Nearest to american: sherry, alexis, selectively, canadian, melvyn, tlingit, qantas, psychotherapist,
# Nearest to may: be, or, risky, rarely, buprenorphine, day, although, globemaster,
# Nearest to nine: one, zero, two, four, six, three, five, eight,
# Nearest to an: a, the, of, or, whose, is, for, external,
# Nearest to d: khayy, rietveld, potato, gastronomique, grotius, osgood, cloves, successors,
# Nearest to called: postings, in, the, which, poudre, it, a, other,
# Nearest to something: preferring, pike, hellish, stimulated, keeping, centigrade, fished, chatting,
# Nearest to units: si, metre, makeup, prespa, fortify, unit, targeting, skenderbeg,
# Nearest to question: answer, syracuse, hideki, insecure, brugge, economist, aumann, duhem,
# Nearest to know: you, i, don, myself, wish, xyzzy, want, extradition,
# Nearest to channel: wootz, channels, univision, licence, eurosceptics, atlantic, headland, tig,
# Nearest to primarily: their, of, buttery, quixote, moths, as, arrondissement, flowed,
# Nearest to file: canso, wandering, maclisp, chessgames, viacom, drukqs, laine, autonegotiation,
# Nearest to dr: attaining, antiseptic, accreditation, underway, rushton, nabba, acrylics, rables,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.8410 0.4370 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.7850 0.4240 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.8102 0.4322 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.8055 0.6458 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.8352 0.4472 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.7987 0.4657 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.8071 0.4349 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.8269 293.2924 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.7680 0.4461 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.7533 0.4536 sec/batch
# Nearest to th: century, centuries, anniversary, modern, rd, eleventh, gregorian, gatherers,
# Nearest to four: two, five, one, three, seven, six, zero, nine,
# Nearest to american: selectively, alexis, sherry, canadian, civilizations, qantas, infidelity, brancusi,
# Nearest to may: be, or, rarely, risky, is, buprenorphine, day, although,
# Nearest to nine: one, zero, four, two, six, three, eight, five,
# Nearest to an: a, the, of, or, is, external, which, by,
# Nearest to d: khayy, potato, rietveld, osgood, grotius, successors, cloves, gastronomique,
# Nearest to called: in, postings, it, which, the, poudre, other, a,
# Nearest to something: pike, preferring, hellish, stimulated, keeping, lusthog, chatting, fished,
# Nearest to units: si, makeup, metre, prespa, targeting, fortify, skenderbeg, redefined,
# Nearest to question: answer, syracuse, hideki, insecure, economist, brugge, quantized, answers,
# Nearest to know: you, myself, i, don, xyzzy, wish, want, silencer,
# Nearest to channel: channels, wootz, univision, eurosceptics, tig, licence, atlantic, headland,
# Nearest to primarily: of, their, buttery, quixote, moths, is, arrondissement, most,
# Nearest to file: canso, wandering, drukqs, maclisp, laine, viacom, coloureds, chessgames,
# Nearest to dr: attaining, accreditation, underway, antiseptic, rushton, acrylics, nabba, rables,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.8235 74.0232 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.7625 0.5204 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.8768 0.4416 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.8482 0.4637 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.8227 0.4728 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.8090 0.4357 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.7151 0.4727 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.7728 0.4651 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.6626 0.4279 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.8278 0.4267 sec/batch
# Nearest to th: century, anniversary, centuries, eleventh, rd, modern, gregorian, hants,
# Nearest to four: two, five, one, six, three, zero, seven, nine,
# Nearest to american: canadian, alexis, psychotherapist, infidelity, sherry, recipients, selectively, brancusi,
# Nearest to may: or, be, rarely, is, day, risky, buprenorphine, antipsychotics,
# Nearest to nine: one, zero, four, six, two, eight, five, three,
# Nearest to an: a, the, of, or, is, which, for, also,
# Nearest to d: khayy, rietveld, osgood, one, slovenian, grotius, cloves, wolfowitz,
# Nearest to called: in, postings, it, the, a, are, other, which,
# Nearest to something: pike, preferring, hellish, stimulated, chatting, keeping, fished, coughing,
# Nearest to units: si, makeup, metre, prespa, redefined, unit, fortify, targeting,
# Nearest to question: answer, syracuse, hideki, economist, brugge, insecure, quantized, ithaca,
# Nearest to know: you, wish, don, myself, i, xyzzy, want, promulgation,
# Nearest to channel: channels, wootz, univision, eurosceptics, tig, licence, headland, atlantic,
# Nearest to primarily: their, buttery, of, quixote, is, moths, mostly, the,
# Nearest to file: canso, wandering, drukqs, laine, maclisp, brushing, coloureds, ahmad,
# Nearest to dr: attaining, underway, antiseptic, accreditation, acrylics, rushton, rables, nabba,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.8170 0.4393 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.7827 0.5489 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/text8.ckpt

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
